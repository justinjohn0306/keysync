# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import torchvision.transforms as T
import torchvision.io as io

# Load video
video_path = "../data/videos/93pVoxyMT-Y_30_0_0_620.mp4"  # Replace with your video path
video, a, m = io.read_video(video_path, pts_unit="sec", output_format="THWC")

# %%
# Convert to float and normalize to [0,1]
first_frame = video[45]

# Create figure and display first frame
plt.figure(figsize=(10, 10))
plt.imshow(first_frame)

# Add point at (300,400)
plt.plot(450, 450, "ro", markersize=10)  # Red dot with size 10


plt.show()
